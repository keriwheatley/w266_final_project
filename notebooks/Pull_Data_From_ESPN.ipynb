# %% [markdown]
# # Web Scraping

# %%
import bs4
import requests

# %%
page = requests.get('http://www.espn.com/nfl/game?gameId=400999172')

# %%
soup = bs4.BeautifulSoup(page.text, 'html.parser')

# %%
soup.
# Out:
# <!DOCTYPE html>
#
# <html class="no-icon-fonts">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge,chrome=1" http-equiv="x-ua-compatible"/>
# <meta content="initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <link href="http://www.espn.com/nfl/game?gameId=400999172" rel="canonical"/>
# <title>Jaguars vs. Patriots - Game Summary - January 21, 2018 - ESPN</title>
# <meta content="Get a summary of the Jacksonville Jaguars vs. New England Patriots football game" name="description">
# <meta content="" name="news_keywords"/>
# <meta content="" name="keywords"/>
# <meta content="116656161708917" property="fb:app_id"/>
# <meta content="ESPN.com" property="og:site_name"/>
# <meta content="http://www.espn.com/nfl/game?gameId=400999172" property="og:url"/>
# <meta content="Jaguars vs. Patriots - Game Summary - January 21, 2018 - ESPN" property="og:title"/>
# ...
